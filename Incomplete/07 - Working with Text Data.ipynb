# %% [markdown]
# # Working with Text Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset
# - This module's dataset (`chicago.csv`) is a collection of public sector employees in the city of Chicago.
# - Each row inclues the employee's name, position, department, and salary.

# %%
chicago = pd.read_csv('chicago.csv')
chicago = chicago.dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')

# %%
chicago

# %%
chicago.info()

# %% [markdown]
# ## Common String Methods
# - A **Series** has a special `str` attribute that exposes an object with string methods.
# - Access the `str` attribute, then invoke the string method on the nested object.
# - Most method names will match their Python method equivalents (`upper`, `lower`, `title`, etc).

# %%
chicago

# %%
chicago['Position Title'] = chicago['Position Title'].str.title()
chicago

# %%
chicago['Department'] = chicago['Department'].str.replace('MGMNT', 'MANAGEMENT').str.title()
chicago

# %% [markdown]
# ## Filtering with String Methods
# - The `str.contains` method checks whether a substring exists anywhere in the string.
# - The `str.startswith` method checks whether a substring exists at the start of the string.
# - The `str.endswith` method checks whether a substring exists at the end of the string.

# %%
chicago = pd.read_csv('chicago.csv')
chicago = chicago.dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# 0                  $90744.00
# 1                  $84450.00
# 2                  $84450.00
# 3                  $89880.00
# 4                 $106836.00
# ...                      ...
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00
#
# [32062 rows x 4 columns]

# %%
engineer = chicago['Position Title'].str.lower().str.contains('engineer')

# %%
chicago.loc[engineer]
# Out:
#                            Name                Position Title  \
# 4           ABAD JR,  VICENTE M             CIVIL ENGINEER IV
# 10        ABBATEMARCO,  JAMES J             FIRE ENGINEER-EMT
# 20     ABDUL-KARIM,  MUHAMMAD A     ENGINEERING TECHNICIAN VI
# 25         ABDULSATTAR,  MUDHAR             CIVIL ENGINEER II
# 34           ABRAHAM,  GIRLEY T             CIVIL ENGINEER IV
# ...                         ...                           ...
# 31975         ZINCHUK,  BRIAN C    OPERATING ENGINEER-GROUP C
# 31994       ZOCHOWSKI,  DAVID J    OPERATING ENGINEER-GROUP C
# 32008           ZOTTA,  SANDINO        MECHANICAL ENGINEER IV
# 32009          ZOUBI,  HAMZEH A       MECHANICAL ENGINEER III
# 32011         ZOVKO,  RICHARD A  HOISTING ENGINEER - MECHANIC
#
#              Department Employee Annual Salary
# 4           WATER MGMNT             $106836.00
# 10                 FIRE             $100320.00
# 20          WATER MGMNT             $108228.00
# 25          WATER MGMNT              $58536.00
# 34          WATER MGMNT             $106836.00
# ...                 ...                    ...
# 31975       WATER MGMNT              $93745.60
# 31994          AVIATION              $93745.60
# 32008       WATER MGMNT             $106836.00
# 32009  GENERAL SERVICES              $64644.00
# 32011  GENERAL SERVICES             $106288.00
#
# [1223 rows x 4 columns]

# %%
starts_with_water = chicago['Department'].str.lower().str.startswith('water')
chicago[starts_with_water]
# Out:
#                            Name             Position Title   Department  \
# 0               AARON,  ELVIA J           WATER RATE TAKER  WATER MGMNT
# 4           ABAD JR,  VICENTE M          CIVIL ENGINEER IV  WATER MGMNT
# 20     ABDUL-KARIM,  MUHAMMAD A  ENGINEERING TECHNICIAN VI  WATER MGMNT
# 25         ABDULSATTAR,  MUDHAR          CIVIL ENGINEER II  WATER MGMNT
# 34           ABRAHAM,  GIRLEY T          CIVIL ENGINEER IV  WATER MGMNT
# ...                         ...                        ...          ...
# 31983           ZIVAT,  MICHAEL       CONSTRUCTION LABORER  WATER MGMNT
# 31984          ZIZUMBO,  DANIEL    POOL MOTOR TRUCK DRIVER  WATER MGMNT
# 32008           ZOTTA,  SANDINO     MECHANICAL ENGINEER IV  WATER MGMNT
# 32038               ZUNO,  ERIK       LABORER - APPRENTICE  WATER MGMNT
# 32050        ZWARYCZ,  THOMAS J    POOL MOTOR TRUCK DRIVER  WATER MGMNT
#
#       Employee Annual Salary
# 0                  $90744.00
# 4                 $106836.00
# 20                $108228.00
# 25                 $58536.00
# 34                $106836.00
# ...                      ...
# 31983              $81536.00
# 31984              $72862.40
# 32008             $106836.00
# 32038              $73382.40
# 32050              $72862.40
#
# [1840 rows x 4 columns]

# %%
starts_with_water = chicago['Position Title'].str.lower().str.endswith(' v')
chicago[starts_with_water]
# Out:
#                            Name            Position Title  \
# 35           ABRAHAM,  GODWIN K  ENGINEERING TECHNICIAN V
# 821                 AN,  NICK H        TRAFFIC ENGINEER V
# 1189          BABAPOUR,  YADI M     FILTRATION ENGINEER V
# 1384             BANEA,  PHILIP            CITY PLANNER V
# 1774   BECQ GIRAUDON,  EMILIE F          CIVIL ENGINEER V
# 4357        CAYANAN,  NARCISO T          CIVIL ENGINEER V
# 4366           CECCHIN,  JOHN R          CIVIL ENGINEER V
# 7227       DONALDSON,  ANGELA M     FILTRATION ENGINEER V
# 7875            EKWUEME,  AMOBI          CIVIL ENGINEER V
# 8099        ESPINOZA,  FERNANDO            CITY PLANNER V
# 8943            FORTE,  KAREN J            CITY PLANNER V
# 11294          HAMEIRI,  AVIKAM          CIVIL ENGINEER V
# 12285       HIGGINS,  WILLIAM M            CITY PLANNER V
# 12882      HUGHES,  GWENDOLYN R     FILTRATION ENGINEER V
# 14276          JURCA,  VASILE M          CIVIL ENGINEER V
# 14777         KHAN,  MOHAMMAD N  ENGINEERING TECHNICIAN V
# 15141        KOLDAN,  ANTHONY W  ENGINEERING TECHNICIAN V
# 17050           MADIA,  JAMES J          CIVIL ENGINEER V
# 17782         MATERRE,  DARYL F     MECHANICAL ENGINEER V
# 19295         MOHAMMED,  SYED R  ENGINEERING TECHNICIAN V
# 20410        NELSON,  WILLIAM G          CIVIL ENGINEER V
# 20786          NWOKEJI,  THOMAS          CIVIL ENGINEER V
# 21879           PATE,  ONEIDA R            CITY PLANNER V
# 23256        RAINEY,  ANTHONY H          CIVIL ENGINEER V
# 23831        RHYMES,  MICHELE A            CITY PLANNER V
# 24185         ROBERTS,  BRIAN J        TRAFFIC ENGINEER V
# 26113            SHAH,  DIPAK K  ENGINEERING TECHNICIAN V
# 26604    SKIADOPOULOS,  FRANK L     FILTRATION ENGINEER V
# 27345        STALLA,  BRIDGET C          CIVIL ENGINEER V
# 27780           STUCK,  ZENON J          CIVIL ENGINEER V
# 28218          TAYLOR,  DARIN E  ENGINEERING TECHNICIAN V
# 28827        TORRES,  MICHAEL W  ENGINEERING TECHNICIAN V
# 29785           VITALO,  JOHN A  ENGINEERING TECHNICIAN V
# 30187        WARNOCK,  THOMAS W          CIVIL ENGINEER V
# 30326           WATSON,  KARL B     MECHANICAL ENGINEER V
# 31293       WISNAR,  CLARENCE A     FILTRATION ENGINEER V
# 31623             YANG,  LUYANG          CIVIL ENGINEER V
#
#                   Department Employee Annual Salary
# 35          BUSINESS AFFAIRS              $98616.00
# 821               TRANSPORTN             $103644.00
# 1189             WATER MGMNT             $116784.00
# 1384              TRANSPORTN              $66768.00
# 1774              TRANSPORTN             $116784.00
# 4357              TRANSPORTN             $116784.00
# 4366              TRANSPORTN             $116784.00
# 7227             WATER MGMNT             $116784.00
# 7875              TRANSPORTN             $116784.00
# 8099   COMMUNITY DEVELOPMENT              $84996.00
# 8943   COMMUNITY DEVELOPMENT              $82668.00
# 11294              BUILDINGS             $116784.00
# 12285             TRANSPORTN              $66768.00
# 12882            WATER MGMNT             $116784.00
# 14276             TRANSPORTN             $116784.00
# 14777                FINANCE              $89880.00
# 15141             TRANSPORTN              $85764.00
# 17050             TRANSPORTN             $116784.00
# 17782            WATER MGMNT             $103716.00
# 19295             TRANSPORTN              $98616.00
# 20410            WATER MGMNT              $93036.00
# 20786              BUILDINGS             $116784.00
# 21879  COMMUNITY DEVELOPMENT              $82668.00
# 23256             TRANSPORTN             $116784.00
# 23831  COMMUNITY DEVELOPMENT              $82668.00
# 24185             TRANSPORTN              $85848.00
# 26113            WATER MGMNT              $89880.00
# 26604            WATER MGMNT             $116784.00
# 27345             TRANSPORTN             $116784.00
# 27780             TRANSPORTN             $116784.00
# 28218                   OEMC              $98616.00
# 28827            WATER MGMNT              $98616.00
# 29785                FINANCE              $89880.00
# 30187             TRANSPORTN             $116784.00
# 30326               AVIATION              $96768.00
# 31293            WATER MGMNT             $116784.00
# 31623             TRANSPORTN             $116784.00

# %% [markdown]
# ## String Methods on Index and Columns
# - Use the `index` and `columns` attributes to access the **DataFrame** index/column labels.
# - These objects support string methods via their own `str` attribute.

# %% [markdown]
# ## The split Method
# - The `str.split` method splits a string by the occurrence of a delimiter. Pandas returns a **Series** of lists.
# - Use the `str.get` method to access a nested list element by its index position.

# %% [markdown]
# ## More Practice with Splits

# %% [markdown]
# ## The expand and n Parameters of the split Method
# - The `expand` parameter returns a **DataFrame** instead of a **Series** of lists.
# - The `n` parameter limits the number of splits.
